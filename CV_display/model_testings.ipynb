# %%
import tensorflow as tf
import keras
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dense,Dropout,Activation,Flatten,BatchNormalization
from keras.layers import Conv2D,MaxPooling2D
import os
import matplotlib.pyplot as plt

# %%
# Check GPU Avaialability
tf.test.is_built_with_cuda()
# Out:
# True

# %%
# Constants for the model
NUM_CLASSES = 5
CLASSES = ["Angry", "Happy", "Neutral", "sad", "Suprise"]
IMG_ROWS = 48
IMG_COLS = 48

num_train_samples = 24176
num_validation_samples = 3006

# Hyperparams
batch_size = 64

# %%
# Data Directory
TRAIN_DATA_DIR = r"C:\Users\markd\Documents\fer2013\train"
VAL_DATA_DIR = r"C:\Users\markd\Documents\fer2013\validation"

# %%
# Image augmentation
# only augment the training set but normalize both inputs
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=30,
    shear_range=0.3,
    zoom_range=0.3,
    width_shift_range=0.4,
    height_shift_range=0.4,
    horizontal_flip=True,
    fill_mode='nearest')

validation_datagen = ImageDataGenerator(rescale=1./255)

# %%
# Define Generators
train_generator = train_datagen.flow_from_directory(
 TRAIN_DATA_DIR,
 color_mode='grayscale',
 target_size=(IMG_ROWS,IMG_COLS),
 batch_size=batch_size,
 class_mode='categorical',
 shuffle=True)

validation_generator = validation_datagen.flow_from_directory(
 VAL_DATA_DIR,
 color_mode='grayscale',
 target_size=(IMG_ROWS,IMG_COLS),
 batch_size=batch_size,
 class_mode='categorical',
 shuffle=True)
# Out:
# Found 24256 images belonging to 5 classes.
# Found 3006 images belonging to 5 classes.

# %%
# Ploting helper functions
def plot_loss(hist):
    plt.title("")
    plt.plot(hist.history['loss'])
    plt.plot(hist.history['val_loss'])
    plt.xlabel("# Epochs")
    plt.ylabel("Loss")
    plt.show()

# Plot results
def plot_acc(hist):
    plt.title("")
    plt.plot(hist.history['accuracy'])
    plt.plot(hist.history['val_accuracy'])
    plt.xlabel("# Epochs")
    plt.ylabel("accuracy")
    plt.show()

# %%
# Define Sequential Model
model = Sequential([
    ## CONV LAYERS 
    # Block 1
    Conv2D(32,(3,3),padding='same',kernel_initializer='he_normal', input_shape=(IMG_ROWS,IMG_COLS,1)),
    Activation('elu'),
    BatchNormalization(),
    Conv2D(32,(3,3),padding='same',kernel_initializer='he_normal'),
    Activation('elu'),
    BatchNormalization(),
    Conv2D(64,(3,3),padding='same',kernel_initializer='he_normal'),
    Activation('elu'),
    BatchNormalization(),
    MaxPooling2D(pool_size=(2,2)),
    Dropout(0.3),

    # Block 2
    Conv2D(64,(3,3),padding='same',kernel_initializer='he_normal'),
    Activation('elu'),
    BatchNormalization(),
    Conv2D(64,(3,3),padding='same',kernel_initializer='he_normal'),
    Activation('elu'),
    BatchNormalization(),
    Conv2D(128,(3,3),padding='same',kernel_initializer='he_normal'),
    Activation('elu'),
    BatchNormalization(),
    MaxPooling2D(pool_size=(2,2)),
    Dropout(0.3),

    # Block 3
    Conv2D(128,(3,3),padding='same',kernel_initializer='he_normal'),
    Activation('elu'),
    BatchNormalization(),
    Conv2D(128,(3,3),padding='same',kernel_initializer='he_normal'),
    Activation('elu'),
    BatchNormalization(),
    Conv2D(256,(3,3),padding='same',kernel_initializer='he_normal'),
    Activation('elu'),
    BatchNormalization(),
    MaxPooling2D(pool_size=(2,2)),
    Dropout(0.3),

    # Block 4
    Conv2D(256,(3,3),padding='same',kernel_initializer='he_normal'),
    Activation('elu'),
    BatchNormalization(),
    Conv2D(256,(3,3),padding='same',kernel_initializer='he_normal'),
    Activation('elu'),
    BatchNormalization(),
    Conv2D(512,(3,3),padding='same',kernel_initializer='he_normal'),
    Activation('elu'),
    BatchNormalization(),
    MaxPooling2D(pool_size=(2,2)),
    Dropout(0.3),

    ## FC LAYERS
    # Block 5
    Flatten(),
    Dense(64,kernel_initializer='he_normal'),
    Activation('elu'),
    BatchNormalization(),
    Dropout(0.5),

    # Block 6
    Flatten(),
    Dense(64,kernel_initializer='he_normal'),
    Activation('elu'),
    BatchNormalization(),
    Dropout(0.5),

    # Block 7
    Dense(NUM_CLASSES,kernel_initializer='he_normal'),
    Activation('softmax'),
])

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.01),
               loss='categorical_crossentropy',
               metrics='accuracy')

# %%
print(model.summary())
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_86 (Conv2D)          (None, 48, 48, 32)        320
#
#  activation_110 (Activation)  (None, 48, 48, 32)       0
#
#  batch_normalization_102 (Ba  (None, 48, 48, 32)       128
#  tchNormalization)
#
#  conv2d_87 (Conv2D)          (None, 48, 48, 32)        9248
#
#  activation_111 (Activation)  (None, 48, 48, 32)       0
#
#  batch_normalization_103 (Ba  (None, 48, 48, 32)       128
#  tchNormalization)
#
#  conv2d_88 (Conv2D)          (None, 48, 48, 64)        18496
#
#  activation_112 (Activation)  (None, 48, 48, 64)       0
#
#  batch_normalization_104 (Ba  (None, 48, 48, 64)       256
#  tchNormalization)
#
#  max_pooling2d_36 (MaxPoolin  (None, 24, 24, 64)       0
#  g2D)
#
#  dropout_48 (Dropout)        (None, 24, 24, 64)        0
#
#  conv2d_89 (Conv2D)          (None, 24, 24, 64)        36928
#
#  activation_113 (Activation)  (None, 24, 24, 64)       0
#
#  batch_normalization_105 (Ba  (None, 24, 24, 64)       256
#  tchNormalization)
#
#  conv2d_90 (Conv2D)          (None, 24, 24, 64)        36928
#
#  activation_114 (Activation)  (None, 24, 24, 64)       0
#
#  batch_normalization_106 (Ba  (None, 24, 24, 64)       256
#  tchNormalization)
#
#  conv2d_91 (Conv2D)          (None, 24, 24, 128)       73856
#
#  activation_115 (Activation)  (None, 24, 24, 128)      0
#
#  batch_normalization_107 (Ba  (None, 24, 24, 128)      512
#  tchNormalization)
#
#  max_pooling2d_37 (MaxPoolin  (None, 12, 12, 128)      0
#  g2D)
#
#  dropout_49 (Dropout)        (None, 12, 12, 128)       0
#
#  conv2d_92 (Conv2D)          (None, 12, 12, 128)       147584
#
#  activation_116 (Activation)  (None, 12, 12, 128)      0
#
#  batch_normalization_108 (Ba  (None, 12, 12, 128)      512
#  tchNormalization)
#
#  conv2d_93 (Conv2D)          (None, 12, 12, 128)       147584
#
#  activation_117 (Activation)  (None, 12, 12, 128)      0
#
#  batch_normalization_109 (Ba  (None, 12, 12, 128)      512
#  tchNormalization)
#
#  conv2d_94 (Conv2D)          (None, 12, 12, 256)       295168
#
#  activation_118 (Activation)  (None, 12, 12, 256)      0
#
#  batch_normalization_110 (Ba  (None, 12, 12, 256)      1024
#  tchNormalization)
#
#  max_pooling2d_38 (MaxPoolin  (None, 6, 6, 256)        0
#  g2D)
#
#  dropout_50 (Dropout)        (None, 6, 6, 256)         0
#
#  conv2d_95 (Conv2D)          (None, 6, 6, 256)         590080
#
#  activation_119 (Activation)  (None, 6, 6, 256)        0
#
#  batch_normalization_111 (Ba  (None, 6, 6, 256)        1024
#  tchNormalization)
#
#  conv2d_96 (Conv2D)          (None, 6, 6, 256)         590080
#
#  activation_120 (Activation)  (None, 6, 6, 256)        0
#
#  batch_normalization_112 (Ba  (None, 6, 6, 256)        1024
#  tchNormalization)
#
#  conv2d_97 (Conv2D)          (None, 6, 6, 512)         1180160
#
#  activation_121 (Activation)  (None, 6, 6, 512)        0
#
#  batch_normalization_113 (Ba  (None, 6, 6, 512)        2048
#  tchNormalization)
#
#  max_pooling2d_39 (MaxPoolin  (None, 3, 3, 512)        0
#  g2D)
#
#  dropout_51 (Dropout)        (None, 3, 3, 512)         0
#
#  flatten_16 (Flatten)        (None, 4608)              0
#
#  dense_24 (Dense)            (None, 64)                294976
#
#  activation_122 (Activation)  (None, 64)               0
#
#  batch_normalization_114 (Ba  (None, 64)               256
#  tchNormalization)
#
#  dropout_52 (Dropout)        (None, 64)                0
#
#  flatten_17 (Flatten)        (None, 64)                0
#
#  dense_25 (Dense)            (None, 64)                4160
#
#  activation_123 (Activation)  (None, 64)               0
#
#  batch_normalization_115 (Ba  (None, 64)               256
#  tchNormalization)
#
#  dropout_53 (Dropout)        (None, 64)                0
#
#  dense_26 (Dense)            (None, 5)                 325
#
#  activation_124 (Activation)  (None, 5)                0
#
# =================================================================
# Total params: 3,434,085
# Trainable params: 3,429,989
# Non-trainable params: 4,096
# _________________________________________________________________
# None

# %%
# Fit data
epochs = 50
history = model.fit_generator(
    train_generator,
    steps_per_epoch = num_train_samples // batch_size,
    epochs=epochs,
    validation_data = validation_generator,
    validation_steps = num_validation_samples // batch_size, 
)
# Out:
# Epoch 1/50
# C:\Users\markd\AppData\Local\Temp\ipykernel_29288\3375956205.py:3: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(
# 377/377 [==============================] - 20s 48ms/step - loss: 7.4226 - accuracy: 0.2712 - val_loss: 2.0927 - val_accuracy: 0.2928
# Epoch 2/50
# 377/377 [==============================] - 20s 53ms/step - loss: 2.1297 - accuracy: 0.2953 - val_loss: 1.8633 - val_accuracy: 0.2921
# Epoch 3/50
# 377/377 [==============================] - 18s 47ms/step - loss: 1.9742 - accuracy: 0.2987 - val_loss: 1.8597 - val_accuracy: 0.2908
# Epoch 4/50
# 377/377 [==============================] - 18s 47ms/step - loss: 1.9825 - accuracy: 0.2992 - val_loss: 1.9776 - val_accuracy: 0.2938
# Epoch 5/50
# 377/377 [==============================] - 18s 47ms/step - loss: 1.9763 - accuracy: 0.2989 - val_loss: 2.2853 - val_accuracy: 0.2928
# Epoch 6/50
# 377/377 [==============================] - 19s 51ms/step - loss: 2.0728 - accuracy: 0.2989 - val_loss: 2.2457 - val_accuracy: 0.2938
# Epoch 7/50
# 377/377 [==============================] - 18s 49ms/step - loss: 2.0357 - accuracy: 0.2993 - val_loss: 2.0374 - val_accuracy: 0.2901
# Epoch 8/50
# 377/377 [==============================] - 18s 49ms/step - loss: 2.1288 - accuracy: 0.2991 - val_loss: 2.1256 - val_accuracy: 0.2935
# Epoch 9/50
# 377/377 [==============================] - 19s 50ms/step - loss: 2.2010 - accuracy: 0.2992 - val_loss: 2.2106 - val_accuracy: 0.1967
# Epoch 10/50
# 377/377 [==============================] - 19s 50ms/step - loss: 2.3248 - accuracy: 0.2984 - val_loss: 2.1240 - val_accuracy: 0.2911
# Epoch 11/50
# 377/377 [==============================] - 19s 50ms/step - loss: 2.2670 - accuracy: 0.2985 - val_loss: 2.4199 - val_accuracy: 0.2928
# Epoch 12/50
# 377/377 [==============================] - 18s 48ms/step - loss: 2.2874 - accuracy: 0.2971 - val_loss: 3.9115 - val_accuracy: 0.1379
# Epoch 13/50
# 377/377 [==============================] - 18s 48ms/step - loss: 2.2336 - accuracy: 0.2986 - val_loss: 2.4498 - val_accuracy: 0.2928
# Epoch 14/50
# 377/377 [==============================] - 19s 50ms/step - loss: 2.2176 - accuracy: 0.2983 - val_loss: 2.3587 - val_accuracy: 0.2918
# Epoch 15/50
# 377/377 [==============================] - 19s 50ms/step - loss: 2.3400 - accuracy: 0.2981 - val_loss: 2.3497 - val_accuracy: 0.2928
# Epoch 16/50
# 377/377 [==============================] - 19s 49ms/step - loss: 2.5057 - accuracy: 0.2987 - val_loss: 2.6895 - val_accuracy: 0.2928
# Epoch 17/50
# 377/377 [==============================] - 19s 50ms/step - loss: 2.1444 - accuracy: 0.2969 - val_loss: 2.2106 - val_accuracy: 0.2945
# Epoch 18/50
# 377/377 [==============================] - 23s 60ms/step - loss: 2.4950 - accuracy: 0.2982 - val_loss: 2.1265 - val_accuracy: 0.2911
# Epoch 19/50
# 377/377 [==============================] - 25s 66ms/step - loss: 2.1067 - accuracy: 0.2986 - val_loss: 1.9080 - val_accuracy: 0.2921
# Epoch 20/50
# 377/377 [==============================] - 25s 65ms/step - loss: 1.9937 - accuracy: 0.2982 - val_loss: 2.3283 - val_accuracy: 0.2785
# Epoch 21/50
# 377/377 [==============================] - 24s 65ms/step - loss: 2.0870 - accuracy: 0.2966 - val_loss: 2.1134 - val_accuracy: 0.2942
# Epoch 22/50
# 377/377 [==============================] - 24s 64ms/step - loss: 2.0668 - accuracy: 0.2978 - val_loss: 1.9580 - val_accuracy: 0.2914
# Epoch 23/50
# 377/377 [==============================] - 24s 64ms/step - loss: 2.0527 - accuracy: 0.2972 - val_loss: 2.1838 - val_accuracy: 0.2935
# Epoch 24/50
# 377/377 [==============================] - 18s 49ms/step - loss: 2.1915 - accuracy: 0.2969 - val_loss: 2.2978 - val_accuracy: 0.2938
# Epoch 25/50
# 377/377 [==============================] - 20s 52ms/step - loss: 2.0229 - accuracy: 0.2979 - val_loss: 1.8886 - val_accuracy: 0.2921
# Epoch 26/50
# 377/377 [==============================] - 18s 48ms/step - loss: 2.0134 - accuracy: 0.2984 - val_loss: 1.8189 - val_accuracy: 0.2911
# Epoch 27/50
# 377/377 [==============================] - 22s 59ms/step - loss: 1.9970 - accuracy: 0.2972 - val_loss: 1.9711 - val_accuracy: 0.2914
# Epoch 28/50
# 377/377 [==============================] - 19s 49ms/step - loss: 2.0195 - accuracy: 0.2989 - val_loss: 2.0025 - val_accuracy: 0.2928
# Epoch 29/50
# 377/377 [==============================] - 19s 50ms/step - loss: 1.9950 - accuracy: 0.2976 - val_loss: 1.9419 - val_accuracy: 0.2925
# Epoch 30/50
# 377/377 [==============================] - 18s 48ms/step - loss: 2.1390 - accuracy: 0.2954 - val_loss: 1.9588 - val_accuracy: 0.2918
# Epoch 31/50
# 377/377 [==============================] - 22s 58ms/step - loss: 1.9779 - accuracy: 0.2977 - val_loss: 1.8031 - val_accuracy: 0.2908
# Epoch 32/50
# 147/377 [==========>...................] - ETA: 16s - loss: 1.8788 - accuracy: 0.3019
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[37], line 3
#       1 # Fit data
#       2 epochs = 50
# ----> 3 history = model.fit_generator(
#       4     train_generator,
#       5     steps_per_epoch = num_train_samples // batch_size,
#       6     epochs=epochs,
#       7     validation_data = validation_generator,
#       8     validation_steps = num_validation_samples // batch_size,
#       9 )
#
# File c:\Users\markd\.conda\envs\tf\lib\site-packages\keras\engine\training.py:2507, in Model.fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    2495 """Fits the model on data yielded batch-by-batch by a Python generator.
#    2496
#    2497 DEPRECATED:
#    2498   `Model.fit` now supports generators, so there is no longer any need to
#    2499   use this endpoint.
#    2500 """
#    2501 warnings.warn(
#    2502     "`Model.fit_generator` is deprecated and "
#    2503     "will be removed in a future version. "
#    2504     "Please use `Model.fit`, which supports generators.",
#    2505     stacklevel=2,
#    2506 )
# -> 2507 return self.fit(
#    2508     generator,
#    2509     steps_per_epoch=steps_per_epoch,
#    2510     epochs=epochs,
#    2511     verbose=verbose,
#    2512     callbacks=callbacks,
#    2513     validation_data=validation_data,
#    2514     validation_steps=validation_steps,
#    2515     validation_freq=validation_freq,
#    2516     class_weight=class_weight,
#    2517     max_queue_size=max_queue_size,
#    2518     workers=workers,
#    2519     use_multiprocessing=use_multiprocessing,
#    2520     shuffle=shuffle,
#    2521     initial_epoch=initial_epoch,
#    2522 )
#
# File c:\Users\markd\.conda\envs\tf\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\markd\.conda\envs\tf\lib\site-packages\keras\engine\training.py:1564, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1556 with tf.profiler.experimental.Trace(
#    1557     "train",
#    1558     epoch_num=epoch,
#    (...)
#    1561     _r=1,
#    1562 ):
#    1563     callbacks.on_train_batch_begin(step)
# -> 1564     tmp_logs = self.train_function(iterator)
#    1565     if data_handler.should_sync:
#    1566         context.async_wait()
#
# File c:\Users\markd\.conda\envs\tf\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\markd\.conda\envs\tf\lib\site-packages\tensorflow\python\eager\def_function.py:915, in Function.__call__(self, *args, **kwds)
#     912 compiler = "xla" if self._jit_compile else "nonXla"
#     914 with OptionalXlaContext(self._jit_compile):
# --> 915   result = self._call(*args, **kwds)
#     917 new_tracing_count = self.experimental_get_tracing_count()
#     918 without_tracing = (tracing_count == new_tracing_count)
#
# File c:\Users\markd\.conda\envs\tf\lib\site-packages\tensorflow\python\eager\def_function.py:947, in Function._call(self, *args, **kwds)
#     944   self._lock.release()
#     945   # In this case we have created variables on the first call, so we run the
#     946   # defunned version which is guaranteed to never create variables.
# --> 947   return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948 elif self._stateful_fn is not None:
#     949   # Release the lock early so that multiple threads can perform the call
#     950   # in parallel.
#     951   self._lock.release()
#
# File c:\Users\markd\.conda\envs\tf\lib\site-packages\tensorflow\python\eager\function.py:2496, in Function.__call__(self, *args, **kwargs)
#    2493 with self._lock:
#    2494   (graph_function,
#    2495    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2496 return graph_function._call_flat(
#    2497     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File c:\Users\markd\.conda\envs\tf\lib\site-packages\tensorflow\python\eager\function.py:1862, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1858 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1859 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1860     and executing_eagerly):
#    1861   # No tape is watching; skip to running the function.
# -> 1862   return self._build_call_outputs(self._inference_function.call(
#    1863       ctx, args, cancellation_manager=cancellation_manager))
#    1864 forward_backward = self._select_forward_and_backward_functions(
#    1865     args,
#    1866     possible_gradient_type,
#    1867     executing_eagerly)
#    1868 forward_function, args_with_tangents = forward_backward.forward()
#
# File c:\Users\markd\.conda\envs\tf\lib\site-packages\tensorflow\python\eager\function.py:499, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     497 with _InterpolateFunctionError(self):
#     498   if cancellation_manager is None:
# --> 499     outputs = execute.execute(
#     500         str(self.signature.name),
#     501         num_outputs=self._num_outputs,
#     502         inputs=args,
#     503         attrs=attrs,
#     504         ctx=ctx)
#     505   else:
#     506     outputs = execute.execute_with_cancellation(
#     507         str(self.signature.name),
#     508         num_outputs=self._num_outputs,
#    (...)
#     511         ctx=ctx,
#     512         cancellation_manager=cancellation_manager)
#
# File c:\Users\markd\.conda\envs\tf\lib\site-packages\tensorflow\python\eager\execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# KeyboardInterrupt:

# %%
plot_acc(history)
plot_loss(history)
