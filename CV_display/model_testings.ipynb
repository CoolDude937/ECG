# %%
import tensorflow as tf
import keras.layers as tfkl
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dense,Dropout,Activation,Flatten,BatchNormalization
from keras.layers import Conv2D,MaxPooling2D
import os
import matplotlib.pyplot as plt

# %%
# Check GPU Avaialability
tf.test.is_built_with_cuda()
# Out:
# True

# %%
# Constants for the model
NUM_CLASSES = 5
CLASSES = ["Angry", "Happy", "Neutral", "sad", "Suprise"]
IMG_ROWS = 48
IMG_COLS = 48

num_train_samples = 24176
num_validation_samples = 3006

# Hyperparams
batch_size = 64

# %%
# Data Directory
TRAIN_DATA_DIR = r"C:\Users\markd\Documents\fer2013\train"
VAL_DATA_DIR = r"C:\Users\markd\Documents\fer2013\validation"

# %%
# Image augmentation
# only augment the training set but normalize both inputs
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=30,
    shear_range=0.3,
    zoom_range=0.3,
    width_shift_range=0.4,
    height_shift_range=0.4,
    horizontal_flip=True,
    fill_mode='nearest')

validation_datagen = ImageDataGenerator(rescale=1./255)

# %%
# Define Generators
train_generator = train_datagen.flow_from_directory(
 TRAIN_DATA_DIR,
 color_mode='grayscale',
 target_size=(IMG_ROWS,IMG_COLS),
 batch_size=batch_size,
 class_mode='categorical',
 shuffle=True)

validation_generator = validation_datagen.flow_from_directory(
 VAL_DATA_DIR,
 color_mode='grayscale',
 target_size=(IMG_ROWS,IMG_COLS),
 batch_size=batch_size,
 class_mode='categorical',
 shuffle=True)
# Out:
# Found 24256 images belonging to 5 classes.
# Found 3006 images belonging to 5 classes.

# %%
# Ploting helper functions
def plot_loss(hist):
    plt.title("")
    plt.plot(hist.history['loss'])
    plt.plot(hist.history['val_loss'])
    plt.xlabel("# Epochs")
    plt.ylabel("Loss")
    plt.show()

# Plot results
def plot_acc(hist):
    plt.title("")
    plt.plot(hist.history['accuracy'])
    plt.plot(hist.history['val_accuracy'])
    plt.xlabel("# Epochs")
    plt.ylabel("accuracy")
    plt.show()

# %%
# Define Sequential Model
model = Sequential([
    ## CONV LAYERS 
    # Block 1
    Conv2D(64,(3,3),padding='same',kernel_initializer='he_normal', input_shape=(IMG_ROWS,IMG_COLS,1)),
    Activation('elu'),
    BatchNormalization(),
    Conv2D(64,(3,3),padding='same',kernel_initializer='he_normal'),
    Activation('elu'),
    BatchNormalization(),
    Dropout(0.3),

    Conv2D(64,(3,3),padding='same',kernel_initializer='he_normal'),
    Activation('elu'),
    BatchNormalization(),
    MaxPooling2D(pool_size=(2,2)),
    Dropout(0.3),

    # Block 2
    Conv2D(128,(3,3),padding='same',kernel_initializer='he_normal'),
    Activation('elu'),
    BatchNormalization(),
    Conv2D(128,(3,3),padding='same',kernel_initializer='he_normal'),
    Activation('elu'),
    BatchNormalization(),
    Dropout(0.3),

    Conv2D(128,(3,3),padding='same',kernel_initializer='he_normal'),
    Activation('elu'),
    BatchNormalization(),
    Conv2D(128,(3,3),padding='same',kernel_initializer='he_normal'),
    Activation('elu'),
    BatchNormalization(),
    MaxPooling2D(pool_size=(2,2)),
    Dropout(0.3),

    # Block 3
    Conv2D(256,(3,3),padding='same',kernel_initializer='he_normal'),
    Activation('elu'),
    BatchNormalization(),
    Conv2D(256,(3,3),padding='same',kernel_initializer='he_normal'),
    Activation('elu'),
    BatchNormalization(),
    Dropout(0.3),

    Conv2D(256,(3,3),padding='same',kernel_initializer='he_normal'),
    Activation('elu'),
    BatchNormalization(),
    Conv2D(256,(3,3),padding='same',kernel_initializer='he_normal'),
    Activation('elu'),
    BatchNormalization(),
    MaxPooling2D(pool_size=(2,2)),
    Dropout(0.3),

    # Block 4
    Conv2D(512,(3,3),padding='same',kernel_initializer='he_normal'),
    Activation('elu'),
    BatchNormalization(),
    Conv2D(512,(3,3),padding='same',kernel_initializer='he_normal'),
    Activation('elu'),
    BatchNormalization(),
    Dropout(0.3),

    Conv2D(512,(3,3),padding='same',kernel_initializer='he_normal'),
    Activation('elu'),
    BatchNormalization(),
    MaxPooling2D(pool_size=(2,2)),
    Dropout(0.3),

    ## FC LAYERS
    # Block 5
    Flatten(),
    Dense(128,kernel_initializer='he_normal'),
    Activation('elu'),
    BatchNormalization(),
    Dropout(0.5),

    # Block 6
    Flatten(),
    Dense(64,kernel_initializer='he_normal'),
    Activation('elu'),
    BatchNormalization(),
    Dropout(0.5),

    # Block 7
    Dense(NUM_CLASSES,kernel_initializer='he_normal'),
    Activation('softmax'),
])

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.01),
               loss='categorical_crossentropy',
               metrics='accuracy')

# %%
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 48, 48, 64)        640
#
#  activation (Activation)     (None, 48, 48, 64)        0
#
#  batch_normalization (BatchN  (None, 48, 48, 64)       256
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 48, 48, 64)        36928
#
#  activation_1 (Activation)   (None, 48, 48, 64)        0
#
#  batch_normalization_1 (Batc  (None, 48, 48, 64)       256
#  hNormalization)
#
#  dropout (Dropout)           (None, 48, 48, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 48, 48, 64)        36928
#
#  activation_2 (Activation)   (None, 48, 48, 64)        0
#
#  batch_normalization_2 (Batc  (None, 48, 48, 64)       256
#  hNormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 24, 24, 64)       0
#  )
#
#  dropout_1 (Dropout)         (None, 24, 24, 64)        0
#
#  conv2d_3 (Conv2D)           (None, 24, 24, 128)       73856
#
#  activation_3 (Activation)   (None, 24, 24, 128)       0
#
#  batch_normalization_3 (Batc  (None, 24, 24, 128)      512
#  hNormalization)
#
#  conv2d_4 (Conv2D)           (None, 24, 24, 128)       147584
#
#  activation_4 (Activation)   (None, 24, 24, 128)       0
#
#  batch_normalization_4 (Batc  (None, 24, 24, 128)      512
#  hNormalization)
#
#  dropout_2 (Dropout)         (None, 24, 24, 128)       0
#
#  conv2d_5 (Conv2D)           (None, 24, 24, 128)       147584
#
#  activation_5 (Activation)   (None, 24, 24, 128)       0
#
#  batch_normalization_5 (Batc  (None, 24, 24, 128)      512
#  hNormalization)
#
#  conv2d_6 (Conv2D)           (None, 24, 24, 128)       147584
#
#  activation_6 (Activation)   (None, 24, 24, 128)       0
#
#  batch_normalization_6 (Batc  (None, 24, 24, 128)      512
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 12, 12, 128)      0
#  2D)
#
#  dropout_3 (Dropout)         (None, 12, 12, 128)       0
#
#  conv2d_7 (Conv2D)           (None, 12, 12, 256)       295168
#
#  activation_7 (Activation)   (None, 12, 12, 256)       0
#
#  batch_normalization_7 (Batc  (None, 12, 12, 256)      1024
#  hNormalization)
#
#  conv2d_8 (Conv2D)           (None, 12, 12, 256)       590080
#
#  activation_8 (Activation)   (None, 12, 12, 256)       0
#
#  batch_normalization_8 (Batc  (None, 12, 12, 256)      1024
#  hNormalization)
#
#  dropout_4 (Dropout)         (None, 12, 12, 256)       0
#
#  conv2d_9 (Conv2D)           (None, 12, 12, 256)       590080
#
#  activation_9 (Activation)   (None, 12, 12, 256)       0
#
#  batch_normalization_9 (Batc  (None, 12, 12, 256)      1024
#  hNormalization)
#
#  conv2d_10 (Conv2D)          (None, 12, 12, 256)       590080
#
#  activation_10 (Activation)  (None, 12, 12, 256)       0
#
#  batch_normalization_10 (Bat  (None, 12, 12, 256)      1024
#  chNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 6, 6, 256)        0
#  2D)
#
#  dropout_5 (Dropout)         (None, 6, 6, 256)         0
#
#  conv2d_11 (Conv2D)          (None, 6, 6, 512)         1180160
#
#  activation_11 (Activation)  (None, 6, 6, 512)         0
#
#  batch_normalization_11 (Bat  (None, 6, 6, 512)        2048
#  chNormalization)
#
#  conv2d_12 (Conv2D)          (None, 6, 6, 512)         2359808
#
#  activation_12 (Activation)  (None, 6, 6, 512)         0
#
#  batch_normalization_12 (Bat  (None, 6, 6, 512)        2048
#  chNormalization)
#
#  dropout_6 (Dropout)         (None, 6, 6, 512)         0
#
#  conv2d_13 (Conv2D)          (None, 6, 6, 512)         2359808
#
#  activation_13 (Activation)  (None, 6, 6, 512)         0
#
#  batch_normalization_13 (Bat  (None, 6, 6, 512)        2048
#  chNormalization)
#
#  max_pooling2d_3 (MaxPooling  (None, 3, 3, 512)        0
#  2D)
#
#  dropout_7 (Dropout)         (None, 3, 3, 512)         0
#
#  flatten (Flatten)           (None, 4608)              0
#
#  dense (Dense)               (None, 128)               589952
#
#  activation_14 (Activation)  (None, 128)               0
#
#  batch_normalization_14 (Bat  (None, 128)              512
#  chNormalization)
#
#  dropout_8 (Dropout)         (None, 128)               0
#
#  flatten_1 (Flatten)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  activation_15 (Activation)  (None, 64)                0
#
#  batch_normalization_15 (Bat  (None, 64)               256
#  chNormalization)
#
#  dropout_9 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 5)                 325
#
#  activation_16 (Activation)  (None, 5)                 0
#
# =================================================================
# Total params: 9,168,645
# Trainable params: 9,161,733
# Non-trainable params: 6,912
# _________________________________________________________________
# None

# %%
# Fit data
epochs = 25
history = model.fit_generator(
    train_generator,
    steps_per_epoch = num_train_samples // batch_size,
    epochs=epochs,
    validation_data = validation_generator,
    validation_steps = num_validation_samples // batch_size, 
)
# Out:
# Epoch 1/75
#   1/377 [..............................] - ETA: 45s - loss: 0.9514 - accuracy: 0.6719
# C:\Users\markd\AppData\Local\Temp\ipykernel_14076\704300924.py:3: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(
# 377/377 [==============================] - 30s 79ms/step - loss: 1.0317 - accuracy: 0.5953 - val_loss: 1.4029 - val_accuracy: 0.5645
# Epoch 2/75
# 377/377 [==============================] - 30s 79ms/step - loss: 1.0244 - accuracy: 0.6025 - val_loss: 1.7237 - val_accuracy: 0.5598
# Epoch 3/75
# 377/377 [==============================] - 30s 79ms/step - loss: 1.0212 - accuracy: 0.6041 - val_loss: 1.5186 - val_accuracy: 0.5931
# Epoch 4/75
# 377/377 [==============================] - 30s 79ms/step - loss: 1.0108 - accuracy: 0.6062 - val_loss: 1.1739 - val_accuracy: 0.6084
# Epoch 5/75
# 377/377 [==============================] - 30s 80ms/step - loss: 1.0049 - accuracy: 0.6113 - val_loss: 1.1653 - val_accuracy: 0.6128
# Epoch 6/75
# 377/377 [==============================] - 30s 81ms/step - loss: 1.0004 - accuracy: 0.6159 - val_loss: 1.4927 - val_accuracy: 0.5744
# Epoch 7/75
# 377/377 [==============================] - 30s 81ms/step - loss: 0.9938 - accuracy: 0.6120 - val_loss: 1.3832 - val_accuracy: 0.5795
# Epoch 8/75
# 377/377 [==============================] - 30s 80ms/step - loss: 0.9838 - accuracy: 0.6190 - val_loss: 1.3222 - val_accuracy: 0.5988
# 377/377 [==============================] - 41s 110ms/step - loss: 0.8937 - accuracy: 0.6625 - val_loss: 1.1944 - val_accuracy: 0.6386
# Epoch 29/75
# 377/377 [==============================] - 36s 95ms/step - loss: 0.8916 - accuracy: 0.6639 - val_loss: 1.2224 - val_accuracy: 0.6185
# Epoch 30/75
# 377/377 [==============================] - 30s 81ms/step - loss: 0.8943 - accuracy: 0.6601 - val_loss: 1.2204 - val_accuracy: 0.6301
# Epoch 31/75
# 377/377 [==============================] - 30s 81ms/step - loss: 0.8750 - accuracy: 0.6674 - val_loss: 1.2913 - val_accuracy: 0.6175
# Epoch 32/75
# 377/377 [==============================] - 31s 81ms/step - loss: 0.8702 - accuracy: 0.6730 - val_loss: 1.1864 - val_accuracy: 0.6301
# Epoch 33/75
# 377/377 [==============================] - 31s 81ms/step - loss: 0.8667 - accuracy: 0.6681 - val_loss: 1.2956 - val_accuracy: 0.5995
# Epoch 34/75
# 377/377 [==============================] - 31s 81ms/step - loss: 0.8756 - accuracy: 0.6715 - val_loss: 1.1626 - val_accuracy: 0.6094
# Epoch 35/75
# 169/377 [============>.................] - ETA: 16s - loss: 0.8628 - accuracy: 0.6746
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[32], line 3
#       1 # Fit data
#       2 epochs = 75
# ----> 3 history = model.fit_generator(
#       4     train_generator,
#       5     steps_per_epoch = num_train_samples // batch_size,
#       6     epochs=epochs,
#       7     validation_data = validation_generator,
#       8     validation_steps = num_validation_samples // batch_size,
#       9 )
#
# File c:\Users\markd\.conda\envs\tf\lib\site-packages\keras\engine\training.py:2507, in Model.fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    2495 """Fits the model on data yielded batch-by-batch by a Python generator.
#    2496
#    2497 DEPRECATED:
#    2498   `Model.fit` now supports generators, so there is no longer any need to
#    2499   use this endpoint.
#    2500 """
#    2501 warnings.warn(
#    2502     "`Model.fit_generator` is deprecated and "
#    2503     "will be removed in a future version. "
#    2504     "Please use `Model.fit`, which supports generators.",
#    2505     stacklevel=2,
#    2506 )
# -> 2507 return self.fit(
#    2508     generator,
#    2509     steps_per_epoch=steps_per_epoch,
#    2510     epochs=epochs,
#    2511     verbose=verbose,
#    2512     callbacks=callbacks,
#    2513     validation_data=validation_data,
#    2514     validation_steps=validation_steps,
#    2515     validation_freq=validation_freq,
#    2516     class_weight=class_weight,
#    2517     max_queue_size=max_queue_size,
#    2518     workers=workers,
#    2519     use_multiprocessing=use_multiprocessing,
#    2520     shuffle=shuffle,
#    2521     initial_epoch=initial_epoch,
#    2522 )
#
# File c:\Users\markd\.conda\envs\tf\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\markd\.conda\envs\tf\lib\site-packages\keras\engine\training.py:1564, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1556 with tf.profiler.experimental.Trace(
#    1557     "train",
#    1558     epoch_num=epoch,
#    (...)
#    1561     _r=1,
#    1562 ):
#    1563     callbacks.on_train_batch_begin(step)
# -> 1564     tmp_logs = self.train_function(iterator)
#    1565     if data_handler.should_sync:
#    1566         context.async_wait()
#
# File c:\Users\markd\.conda\envs\tf\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\markd\.conda\envs\tf\lib\site-packages\tensorflow\python\eager\def_function.py:915, in Function.__call__(self, *args, **kwds)
#     912 compiler = "xla" if self._jit_compile else "nonXla"
#     914 with OptionalXlaContext(self._jit_compile):
# --> 915   result = self._call(*args, **kwds)
#     917 new_tracing_count = self.experimental_get_tracing_count()
#     918 without_tracing = (tracing_count == new_tracing_count)
#
# File c:\Users\markd\.conda\envs\tf\lib\site-packages\tensorflow\python\eager\def_function.py:947, in Function._call(self, *args, **kwds)
#     944   self._lock.release()
#     945   # In this case we have created variables on the first call, so we run the
#     946   # defunned version which is guaranteed to never create variables.
# --> 947   return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948 elif self._stateful_fn is not None:
#     949   # Release the lock early so that multiple threads can perform the call
#     950   # in parallel.
#     951   self._lock.release()
#
# File c:\Users\markd\.conda\envs\tf\lib\site-packages\tensorflow\python\eager\function.py:2496, in Function.__call__(self, *args, **kwargs)
#    2493 with self._lock:
#    2494   (graph_function,
#    2495    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2496 return graph_function._call_flat(
#    2497     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File c:\Users\markd\.conda\envs\tf\lib\site-packages\tensorflow\python\eager\function.py:1862, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1858 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1859 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1860     and executing_eagerly):
#    1861   # No tape is watching; skip to running the function.
# -> 1862   return self._build_call_outputs(self._inference_function.call(
#    1863       ctx, args, cancellation_manager=cancellation_manager))
#    1864 forward_backward = self._select_forward_and_backward_functions(
#    1865     args,
#    1866     possible_gradient_type,
#    1867     executing_eagerly)
#    1868 forward_function, args_with_tangents = forward_backward.forward()
#
# File c:\Users\markd\.conda\envs\tf\lib\site-packages\tensorflow\python\eager\function.py:499, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     497 with _InterpolateFunctionError(self):
#     498   if cancellation_manager is None:
# --> 499     outputs = execute.execute(
#     500         str(self.signature.name),
#     501         num_outputs=self._num_outputs,
#     502         inputs=args,
#     503         attrs=attrs,
#     504         ctx=ctx)
#     505   else:
#     506     outputs = execute.execute_with_cancellation(
#     507         str(self.signature.name),
#     508         num_outputs=self._num_outputs,
#    (...)
#     511         ctx=ctx,
#     512         cancellation_manager=cancellation_manager)
#
# File c:\Users\markd\.conda\envs\tf\lib\site-packages\tensorflow\python\eager\execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# KeyboardInterrupt:

# %%
plot_acc(history)
plot_loss(history)

# %%
# ResNet 50 Residual Blocks
def identity_block(X, f, filters, training=True, initializer = tf.keras.initializers.random_uniform):
    """
    Implementation of the identity block
    
    Arguments:
    X -- input tensor of shape (m, n_H_prev, n_W_prev, n_C_prev)
    f -- integer, specifying the shape of the middle CONV's window for the main path
    filters -- python list of integers, defining the number of filters in the CONV layers of the main path
    training -- True: Behave in training mode
                False: Behave in inference mode
    initializer -- to set up the initial weights of a layer. Equals to random uniform initializer
    
    Returns:
    X -- output of the identity block, tensor of shape (m, n_H, n_W, n_C)
    """
    # Retrieve Filters
    F1, F2, F3 = filters
    
    # saving shortcut value
    X_shortcut = X
    
    # First component
    X = tfkl.Conv2D(filters = F1, kernel_size = 1, strides = (1,1), padding = 'valid', kernel_initializer = initializer(seed=0))(X)
    X = tfkl.BatchNormalization(axis = 3)(X, training = training) # Default axis
    X = tfkl.Activation('relu')(X)
    
    ## Second component 
    X = tfkl.Conv2D(filters = F2, kernel_size = f, strides = (1,1), padding= 'same', kernel_initializer = initializer(seed=0))(X)
    X = tfkl.BatchNormalization(axis = 3)(X, training = training) # Default axis
    X = tfkl.Activation('relu')(X)

    ## Third component
    X = tfkl.Conv2D(filters = F3, kernel_size = 1, strides = (1,1), padding= 'valid', kernel_initializer = initializer(seed=0))(X)
    X = tfkl.BatchNormalization(axis = 3)(X, training = training) # Default axis

    ## Add shortcut value back into main path
    X = tfkl.Add()([X, X_shortcut])
    X = tfkl.Activation('relu')(X) 

    return X

# %%
def convolutional_block(X, f, filters, s = 2, training=True, initializer=tf.keras.initializers.glorot_uniform):
    """
    Implementation of the convolutional block
    
    Arguments:
    X -- input tensor of shape (m, n_H_prev, n_W_prev, n_C_prev)
    f -- integer, specifying the shape of the middle CONV's window for the main path
    filters -- python list of integers, defining the number of filters in the CONV layers of the main path
    s -- Integer, specifying the stride to be used
    training -- True: Behave in training mode
                False: Behave in inference mode
    initializer -- to set up the initial weights of a layer. Equals to Glorot uniform initializer, 
                   also called Xavier uniform initializer.
    
    Returns:
    X -- output of the convolutional block, tensor of shape (m, n_H, n_W, n_C)
    """
    # Retrieve Filters
    F1, F2, F3 = filters
    
    # Save the input value
    X_shortcut = X

    ##### MAIN PATH #####
    # First component of main path
    X = tfkl.Conv2D(filters = F1, kernel_size = 1, strides = (s, s), padding='valid', kernel_initializer = initializer(seed=0))(X)
    X = tfkl.BatchNormalization(axis = 3)(X, training=training)
    X = tfkl.Activation('relu')(X)

    ## Second component of main path
    X = tfkl.Conv2D(filters = F2, kernel_size = f, strides = (1, 1), padding='same', kernel_initializer = initializer(seed=0))(X)
    X = tfkl.BatchNormalization(axis = 3)(X, training=training)
    X = tfkl.Activation('relu')(X) 

    ## Third component of main path 
    X = tfkl.Conv2D(filters = F3, kernel_size = 1, strides = (1, 1), padding='valid', kernel_initializer = initializer(seed=0))(X)
    X = tfkl.BatchNormalization(axis = 3)(X, training=training)
    
    ##### SHORTCUT PATH #####
    X_shortcut = tfkl.Conv2D(filters = F3, kernel_size = 1, strides = (s, s), padding='valid', kernel_initializer = initializer(seed=0))(X_shortcut)
    X_shortcut = tfkl.BatchNormalization(axis = 3)(X_shortcut, training=training)

    # Add shortcut value to main path
    X = tfkl.Add()([X, X_shortcut])
    X = tfkl.Activation('relu')(X)
    
    return X

# %%
def modified_ResNet50(input_shape = (48, 48, 1), classes = NUM_CLASSES, dropout=0.2):
    """
    Stage-wise implementation of the architecture of the popular ResNet50, with 5th block removed 

    Arguments:
    input_shape -- shape of the images of the dataset
    classes -- integer, number of classes
    dropout -- float (0-1), dropout chance

    Returns:
    model -- a Model() instance in Keras
    """
    
    # Define the input as a tensor with shape input_shape
    X_input = tfkl.Input(input_shape)
    X = tfkl.ZeroPadding2D((3, 3))(X_input)

    # Block 1
    X = tfkl.Conv2D(64, (5,5), strides=2)(X)  # 16 x 16 x 64
    X = tfkl.BatchNormalization(axis = 3)(X)
    X = tfkl.Activation('relu')(X)
    X = tfkl.MaxPooling2D((3, 3), strides=(2, 2))(X)
    X = tfkl.Dropout(dropout)(X)

    # Block 2
    X = convolutional_block(X, f = 3, filters = [64, 64, 256], s = 1)
    X = identity_block(X, 3, [64, 64, 256])
    X = identity_block(X, 3, [64, 64, 256])
    X = tfkl.Dropout(dropout)(X)

    # Block 3
    X = convolutional_block(X, f = 3, filters = [128, 128, 512], s = 2)
    X = identity_block(X, 3, [128, 128, 512])
    X = identity_block(X, 3, [128, 128, 512])
    X = identity_block(X, 3, [128, 128, 512])
    X = tfkl.Dropout(dropout)(X)

    # Block 4
    X = convolutional_block(X, f = 3, filters = [256, 256, 1024], s = 2)
    X = identity_block(X, 3, [256, 256, 1024])
    X = identity_block(X, 3, [256, 256, 1024])
    X = identity_block(X, 3, [256, 256, 1024])
    X = identity_block(X, 3, [256, 256, 1024])
    X = identity_block(X, 3, [256, 256, 1024])
    X = tfkl.Dropout(dropout)(X)  

    # Block 5
    X = convolutional_block(X, f = 3, filters = [512, 512, 2048], s = 1)
    X = identity_block(X, 3, [512, 512, 2048])
    X = identity_block(X, 3, [512, 512, 2048])
    X = tfkl.Dropout(dropout)(X)  

    # FC Block
    X = tfkl.AveragePooling2D()(X)
    X = tfkl.Flatten()(X)
    X = tfkl.Dense(classes, activation='softmax', kernel_initializer = tf.keras.initializers.glorot_uniform(seed=0))(X)

    # Create model
    model = tf.keras.Model(inputs = X_input, outputs = X)
    return model

# %%
resnet_model = modified_ResNet50(dropout=0.2)

# %%
resnet_model.summary()
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_8 (InputLayer)           [(None, 48, 48, 1)]  0           []
#
#  zero_padding2d_7 (ZeroPadding2  (None, 54, 54, 1)   0           ['input_8[0][0]']
#  D)
#
#  conv2d_328 (Conv2D)            (None, 25, 25, 64)   1664        ['zero_padding2d_7[0][0]']
#
#  batch_normalization_330 (Batch  (None, 25, 25, 64)  256         ['conv2d_328[0][0]']
#  Normalization)
#
#  activation_306 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_330[0][0]']
#
#  max_pooling2d_11 (MaxPooling2D  (None, 12, 12, 64)  0           ['activation_306[0][0]']
#  )
#
#  dropout_26 (Dropout)           (None, 12, 12, 64)   0           ['max_pooling2d_11[0][0]']
#
#  conv2d_329 (Conv2D)            (None, 12, 12, 64)   4160        ['dropout_26[0][0]']
#
#  batch_normalization_331 (Batch  (None, 12, 12, 64)  256         ['conv2d_329[0][0]']
#  Normalization)
#
#  activation_307 (Activation)    (None, 12, 12, 64)   0           ['batch_normalization_331[0][0]']
#
#  conv2d_330 (Conv2D)            (None, 12, 12, 64)   36928       ['activation_307[0][0]']
#
#  batch_normalization_332 (Batch  (None, 12, 12, 64)  256         ['conv2d_330[0][0]']
#  Normalization)
#
#  activation_308 (Activation)    (None, 12, 12, 64)   0           ['batch_normalization_332[0][0]']
#
#  conv2d_331 (Conv2D)            (None, 12, 12, 256)  16640       ['activation_308[0][0]']
#
#  conv2d_332 (Conv2D)            (None, 12, 12, 256)  16640       ['dropout_26[0][0]']
#
#  batch_normalization_333 (Batch  (None, 12, 12, 256)  1024       ['conv2d_331[0][0]']
#  Normalization)
#
#  batch_normalization_334 (Batch  (None, 12, 12, 256)  1024       ['conv2d_332[0][0]']
#  Normalization)
#
#  add_95 (Add)                   (None, 12, 12, 256)  0           ['batch_normalization_333[0][0]',
#                                                                   'batch_normalization_334[0][0]']
#
#  activation_309 (Activation)    (None, 12, 12, 256)  0           ['add_95[0][0]']
#
#  conv2d_333 (Conv2D)            (None, 12, 12, 64)   16448       ['activation_309[0][0]']
#
#  batch_normalization_335 (Batch  (None, 12, 12, 64)  256         ['conv2d_333[0][0]']
#  Normalization)
#
#  activation_310 (Activation)    (None, 12, 12, 64)   0           ['batch_normalization_335[0][0]']
#
#  conv2d_334 (Conv2D)            (None, 12, 12, 64)   36928       ['activation_310[0][0]']
#
#  batch_normalization_336 (Batch  (None, 12, 12, 64)  256         ['conv2d_334[0][0]']
#  Normalization)
#
#  activation_311 (Activation)    (None, 12, 12, 64)   0           ['batch_normalization_336[0][0]']
#
#  conv2d_335 (Conv2D)            (None, 12, 12, 256)  16640       ['activation_311[0][0]']
#
#  batch_normalization_337 (Batch  (None, 12, 12, 256)  1024       ['conv2d_335[0][0]']
#  Normalization)
#
#  add_96 (Add)                   (None, 12, 12, 256)  0           ['batch_normalization_337[0][0]',
#                                                                   'activation_309[0][0]']
#
#  activation_312 (Activation)    (None, 12, 12, 256)  0           ['add_96[0][0]']
#
#  conv2d_336 (Conv2D)            (None, 12, 12, 64)   16448       ['activation_312[0][0]']
#
#  batch_normalization_338 (Batch  (None, 12, 12, 64)  256         ['conv2d_336[0][0]']
#  Normalization)
#
#  activation_313 (Activation)    (None, 12, 12, 64)   0           ['batch_normalization_338[0][0]']
#
#  conv2d_337 (Conv2D)            (None, 12, 12, 64)   36928       ['activation_313[0][0]']
#
#  batch_normalization_339 (Batch  (None, 12, 12, 64)  256         ['conv2d_337[0][0]']
#  Normalization)
#
#  activation_314 (Activation)    (None, 12, 12, 64)   0           ['batch_normalization_339[0][0]']
#
#  conv2d_338 (Conv2D)            (None, 12, 12, 256)  16640       ['activation_314[0][0]']
#
#  batch_normalization_340 (Batch  (None, 12, 12, 256)  1024       ['conv2d_338[0][0]']
#  Normalization)
#
#  add_97 (Add)                   (None, 12, 12, 256)  0           ['batch_normalization_340[0][0]',
#                                                                   'activation_312[0][0]']
#
#  activation_315 (Activation)    (None, 12, 12, 256)  0           ['add_97[0][0]']
#
#  dropout_27 (Dropout)           (None, 12, 12, 256)  0           ['activation_315[0][0]']
#
#  conv2d_339 (Conv2D)            (None, 6, 6, 128)    32896       ['dropout_27[0][0]']
#
#  batch_normalization_341 (Batch  (None, 6, 6, 128)   512         ['conv2d_339[0][0]']
#  Normalization)
#
#  activation_316 (Activation)    (None, 6, 6, 128)    0           ['batch_normalization_341[0][0]']
#
#  conv2d_340 (Conv2D)            (None, 6, 6, 128)    147584      ['activation_316[0][0]']
#
#  batch_normalization_342 (Batch  (None, 6, 6, 128)   512         ['conv2d_340[0][0]']
#  Normalization)
#
#  activation_317 (Activation)    (None, 6, 6, 128)    0           ['batch_normalization_342[0][0]']
#
#  conv2d_341 (Conv2D)            (None, 6, 6, 512)    66048       ['activation_317[0][0]']
#
#  conv2d_342 (Conv2D)            (None, 6, 6, 512)    131584      ['dropout_27[0][0]']
#
#  batch_normalization_343 (Batch  (None, 6, 6, 512)   2048        ['conv2d_341[0][0]']
#  Normalization)
#
#  batch_normalization_344 (Batch  (None, 6, 6, 512)   2048        ['conv2d_342[0][0]']
#  Normalization)
#
#  add_98 (Add)                   (None, 6, 6, 512)    0           ['batch_normalization_343[0][0]',
#                                                                   'batch_normalization_344[0][0]']
#
#  activation_318 (Activation)    (None, 6, 6, 512)    0           ['add_98[0][0]']
#
#  conv2d_343 (Conv2D)            (None, 6, 6, 128)    65664       ['activation_318[0][0]']
#
#  batch_normalization_345 (Batch  (None, 6, 6, 128)   512         ['conv2d_343[0][0]']
#  Normalization)
#
#  activation_319 (Activation)    (None, 6, 6, 128)    0           ['batch_normalization_345[0][0]']
#
#  conv2d_344 (Conv2D)            (None, 6, 6, 128)    147584      ['activation_319[0][0]']
#
#  batch_normalization_346 (Batch  (None, 6, 6, 128)   512         ['conv2d_344[0][0]']
#  Normalization)
#
#  activation_320 (Activation)    (None, 6, 6, 128)    0           ['batch_normalization_346[0][0]']
#
#  conv2d_345 (Conv2D)            (None, 6, 6, 512)    66048       ['activation_320[0][0]']
#
#  batch_normalization_347 (Batch  (None, 6, 6, 512)   2048        ['conv2d_345[0][0]']
#  Normalization)
#
#  add_99 (Add)                   (None, 6, 6, 512)    0           ['batch_normalization_347[0][0]',
#                                                                   'activation_318[0][0]']
#
#  activation_321 (Activation)    (None, 6, 6, 512)    0           ['add_99[0][0]']
#
#  conv2d_346 (Conv2D)            (None, 6, 6, 128)    65664       ['activation_321[0][0]']
#
#  batch_normalization_348 (Batch  (None, 6, 6, 128)   512         ['conv2d_346[0][0]']
#  Normalization)
#
#  activation_322 (Activation)    (None, 6, 6, 128)    0           ['batch_normalization_348[0][0]']
#
#  conv2d_347 (Conv2D)            (None, 6, 6, 128)    147584      ['activation_322[0][0]']
#
#  batch_normalization_349 (Batch  (None, 6, 6, 128)   512         ['conv2d_347[0][0]']
#  Normalization)
#
#  activation_323 (Activation)    (None, 6, 6, 128)    0           ['batch_normalization_349[0][0]']
#
#  conv2d_348 (Conv2D)            (None, 6, 6, 512)    66048       ['activation_323[0][0]']
#
#  batch_normalization_350 (Batch  (None, 6, 6, 512)   2048        ['conv2d_348[0][0]']
#  Normalization)
#
#  add_100 (Add)                  (None, 6, 6, 512)    0           ['batch_normalization_350[0][0]',
#                                                                   'activation_321[0][0]']
#
#  activation_324 (Activation)    (None, 6, 6, 512)    0           ['add_100[0][0]']
#
#  conv2d_349 (Conv2D)            (None, 6, 6, 128)    65664       ['activation_324[0][0]']
#
#  batch_normalization_351 (Batch  (None, 6, 6, 128)   512         ['conv2d_349[0][0]']
#  Normalization)
#
#  activation_325 (Activation)    (None, 6, 6, 128)    0           ['batch_normalization_351[0][0]']
#
#  conv2d_350 (Conv2D)            (None, 6, 6, 128)    147584      ['activation_325[0][0]']
#
#  batch_normalization_352 (Batch  (None, 6, 6, 128)   512         ['conv2d_350[0][0]']
#  Normalization)
#
#  activation_326 (Activation)    (None, 6, 6, 128)    0           ['batch_normalization_352[0][0]']
#
#  conv2d_351 (Conv2D)            (None, 6, 6, 512)    66048       ['activation_326[0][0]']
#
#  batch_normalization_353 (Batch  (None, 6, 6, 512)   2048        ['conv2d_351[0][0]']
#  Normalization)
#
#  add_101 (Add)                  (None, 6, 6, 512)    0           ['batch_normalization_353[0][0]',
#                                                                   'activation_324[0][0]']
#
#  activation_327 (Activation)    (None, 6, 6, 512)    0           ['add_101[0][0]']
#
#  dropout_28 (Dropout)           (None, 6, 6, 512)    0           ['activation_327[0][0]']
#
#  conv2d_352 (Conv2D)            (None, 3, 3, 256)    131328      ['dropout_28[0][0]']
#
#  batch_normalization_354 (Batch  (None, 3, 3, 256)   1024        ['conv2d_352[0][0]']
#  Normalization)
#
#  activation_328 (Activation)    (None, 3, 3, 256)    0           ['batch_normalization_354[0][0]']
#
#  conv2d_353 (Conv2D)            (None, 3, 3, 256)    590080      ['activation_328[0][0]']
#
#  batch_normalization_355 (Batch  (None, 3, 3, 256)   1024        ['conv2d_353[0][0]']
#  Normalization)
#
#  activation_329 (Activation)    (None, 3, 3, 256)    0           ['batch_normalization_355[0][0]']
#
#  conv2d_354 (Conv2D)            (None, 3, 3, 1024)   263168      ['activation_329[0][0]']
#
#  conv2d_355 (Conv2D)            (None, 3, 3, 1024)   525312      ['dropout_28[0][0]']
#
#  batch_normalization_356 (Batch  (None, 3, 3, 1024)  4096        ['conv2d_354[0][0]']
#  Normalization)
#
#  batch_normalization_357 (Batch  (None, 3, 3, 1024)  4096        ['conv2d_355[0][0]']
#  Normalization)
#
#  add_102 (Add)                  (None, 3, 3, 1024)   0           ['batch_normalization_356[0][0]',
#                                                                   'batch_normalization_357[0][0]']
#
#  activation_330 (Activation)    (None, 3, 3, 1024)   0           ['add_102[0][0]']
#
#  conv2d_356 (Conv2D)            (None, 3, 3, 256)    262400      ['activation_330[0][0]']
#
#  batch_normalization_358 (Batch  (None, 3, 3, 256)   1024        ['conv2d_356[0][0]']
#  Normalization)
#
#  activation_331 (Activation)    (None, 3, 3, 256)    0           ['batch_normalization_358[0][0]']
#
#  conv2d_357 (Conv2D)            (None, 3, 3, 256)    590080      ['activation_331[0][0]']
#
#  batch_normalization_359 (Batch  (None, 3, 3, 256)   1024        ['conv2d_357[0][0]']
#  Normalization)
#
#  activation_332 (Activation)    (None, 3, 3, 256)    0           ['batch_normalization_359[0][0]']
#
#  conv2d_358 (Conv2D)            (None, 3, 3, 1024)   263168      ['activation_332[0][0]']
#
#  batch_normalization_360 (Batch  (None, 3, 3, 1024)  4096        ['conv2d_358[0][0]']
#  Normalization)
#
#  add_103 (Add)                  (None, 3, 3, 1024)   0           ['batch_normalization_360[0][0]',
#                                                                   'activation_330[0][0]']
#
#  activation_333 (Activation)    (None, 3, 3, 1024)   0           ['add_103[0][0]']
#
#  conv2d_359 (Conv2D)            (None, 3, 3, 256)    262400      ['activation_333[0][0]']
#
#  batch_normalization_361 (Batch  (None, 3, 3, 256)   1024        ['conv2d_359[0][0]']
#  Normalization)
#
#  activation_334 (Activation)    (None, 3, 3, 256)    0           ['batch_normalization_361[0][0]']
#
#  conv2d_360 (Conv2D)            (None, 3, 3, 256)    590080      ['activation_334[0][0]']
#
#  batch_normalization_362 (Batch  (None, 3, 3, 256)   1024        ['conv2d_360[0][0]']
#  Normalization)
#
#  activation_335 (Activation)    (None, 3, 3, 256)    0           ['batch_normalization_362[0][0]']
#
#  conv2d_361 (Conv2D)            (None, 3, 3, 1024)   263168      ['activation_335[0][0]']
#
#  batch_normalization_363 (Batch  (None, 3, 3, 1024)  4096        ['conv2d_361[0][0]']
#  Normalization)
#
#  add_104 (Add)                  (None, 3, 3, 1024)   0           ['batch_normalization_363[0][0]',
#                                                                   'activation_333[0][0]']
#
#  activation_336 (Activation)    (None, 3, 3, 1024)   0           ['add_104[0][0]']
#
#  conv2d_362 (Conv2D)            (None, 3, 3, 256)    262400      ['activation_336[0][0]']
#
#  batch_normalization_364 (Batch  (None, 3, 3, 256)   1024        ['conv2d_362[0][0]']
#  Normalization)
#
#  activation_337 (Activation)    (None, 3, 3, 256)    0           ['batch_normalization_364[0][0]']
#
#  conv2d_363 (Conv2D)            (None, 3, 3, 256)    590080      ['activation_337[0][0]']
#
#  batch_normalization_365 (Batch  (None, 3, 3, 256)   1024        ['conv2d_363[0][0]']
#  Normalization)
#
#  activation_338 (Activation)    (None, 3, 3, 256)    0           ['batch_normalization_365[0][0]']
#
#  conv2d_364 (Conv2D)            (None, 3, 3, 1024)   263168      ['activation_338[0][0]']
#
#  batch_normalization_366 (Batch  (None, 3, 3, 1024)  4096        ['conv2d_364[0][0]']
#  Normalization)
#
#  add_105 (Add)                  (None, 3, 3, 1024)   0           ['batch_normalization_366[0][0]',
#                                                                   'activation_336[0][0]']
#
#  activation_339 (Activation)    (None, 3, 3, 1024)   0           ['add_105[0][0]']
#
#  conv2d_365 (Conv2D)            (None, 3, 3, 256)    262400      ['activation_339[0][0]']
#
#  batch_normalization_367 (Batch  (None, 3, 3, 256)   1024        ['conv2d_365[0][0]']
#  Normalization)
#
#  activation_340 (Activation)    (None, 3, 3, 256)    0           ['batch_normalization_367[0][0]']
#
#  conv2d_366 (Conv2D)            (None, 3, 3, 256)    590080      ['activation_340[0][0]']
#
#  batch_normalization_368 (Batch  (None, 3, 3, 256)   1024        ['conv2d_366[0][0]']
#  Normalization)
#
#  activation_341 (Activation)    (None, 3, 3, 256)    0           ['batch_normalization_368[0][0]']
#
#  conv2d_367 (Conv2D)            (None, 3, 3, 1024)   263168      ['activation_341[0][0]']
#
#  batch_normalization_369 (Batch  (None, 3, 3, 1024)  4096        ['conv2d_367[0][0]']
#  Normalization)
#
#  add_106 (Add)                  (None, 3, 3, 1024)   0           ['batch_normalization_369[0][0]',
#                                                                   'activation_339[0][0]']
#
#  activation_342 (Activation)    (None, 3, 3, 1024)   0           ['add_106[0][0]']
#
#  conv2d_368 (Conv2D)            (None, 3, 3, 256)    262400      ['activation_342[0][0]']
#
#  batch_normalization_370 (Batch  (None, 3, 3, 256)   1024        ['conv2d_368[0][0]']
#  Normalization)
#
#  activation_343 (Activation)    (None, 3, 3, 256)    0           ['batch_normalization_370[0][0]']
#
#  conv2d_369 (Conv2D)            (None, 3, 3, 256)    590080      ['activation_343[0][0]']
#
#  batch_normalization_371 (Batch  (None, 3, 3, 256)   1024        ['conv2d_369[0][0]']
#  Normalization)
#
#  activation_344 (Activation)    (None, 3, 3, 256)    0           ['batch_normalization_371[0][0]']
#
#  conv2d_370 (Conv2D)            (None, 3, 3, 1024)   263168      ['activation_344[0][0]']
#
#  batch_normalization_372 (Batch  (None, 3, 3, 1024)  4096        ['conv2d_370[0][0]']
#  Normalization)
#
#  add_107 (Add)                  (None, 3, 3, 1024)   0           ['batch_normalization_372[0][0]',
#                                                                   'activation_342[0][0]']
#
#  activation_345 (Activation)    (None, 3, 3, 1024)   0           ['add_107[0][0]']
#
#  dropout_29 (Dropout)           (None, 3, 3, 1024)   0           ['activation_345[0][0]']
#
#  conv2d_371 (Conv2D)            (None, 3, 3, 512)    524800      ['dropout_29[0][0]']
#
#  batch_normalization_373 (Batch  (None, 3, 3, 512)   2048        ['conv2d_371[0][0]']
#  Normalization)
#
#  activation_346 (Activation)    (None, 3, 3, 512)    0           ['batch_normalization_373[0][0]']
#
#  conv2d_372 (Conv2D)            (None, 3, 3, 512)    2359808     ['activation_346[0][0]']
#
#  batch_normalization_374 (Batch  (None, 3, 3, 512)   2048        ['conv2d_372[0][0]']
#  Normalization)
#
#  activation_347 (Activation)    (None, 3, 3, 512)    0           ['batch_normalization_374[0][0]']
#
#  conv2d_373 (Conv2D)            (None, 3, 3, 2048)   1050624     ['activation_347[0][0]']
#
#  conv2d_374 (Conv2D)            (None, 3, 3, 2048)   2099200     ['dropout_29[0][0]']
#
#  batch_normalization_375 (Batch  (None, 3, 3, 2048)  8192        ['conv2d_373[0][0]']
#  Normalization)
#
#  batch_normalization_376 (Batch  (None, 3, 3, 2048)  8192        ['conv2d_374[0][0]']
#  Normalization)
#
#  add_108 (Add)                  (None, 3, 3, 2048)   0           ['batch_normalization_375[0][0]',
#                                                                   'batch_normalization_376[0][0]']
#
#  activation_348 (Activation)    (None, 3, 3, 2048)   0           ['add_108[0][0]']
#
#  conv2d_375 (Conv2D)            (None, 3, 3, 512)    1049088     ['activation_348[0][0]']
#
#  batch_normalization_377 (Batch  (None, 3, 3, 512)   2048        ['conv2d_375[0][0]']
#  Normalization)
#
#  activation_349 (Activation)    (None, 3, 3, 512)    0           ['batch_normalization_377[0][0]']
#
#  conv2d_376 (Conv2D)            (None, 3, 3, 512)    2359808     ['activation_349[0][0]']
#
#  batch_normalization_378 (Batch  (None, 3, 3, 512)   2048        ['conv2d_376[0][0]']
#  Normalization)
#
#  activation_350 (Activation)    (None, 3, 3, 512)    0           ['batch_normalization_378[0][0]']
#
#  conv2d_377 (Conv2D)            (None, 3, 3, 2048)   1050624     ['activation_350[0][0]']
#
#  batch_normalization_379 (Batch  (None, 3, 3, 2048)  8192        ['conv2d_377[0][0]']
#  Normalization)
#
#  add_109 (Add)                  (None, 3, 3, 2048)   0           ['batch_normalization_379[0][0]',
#                                                                   'activation_348[0][0]']
#
#  activation_351 (Activation)    (None, 3, 3, 2048)   0           ['add_109[0][0]']
#
#  conv2d_378 (Conv2D)            (None, 3, 3, 512)    1049088     ['activation_351[0][0]']
#
#  batch_normalization_380 (Batch  (None, 3, 3, 512)   2048        ['conv2d_378[0][0]']
#  Normalization)
#
#  activation_352 (Activation)    (None, 3, 3, 512)    0           ['batch_normalization_380[0][0]']
#
#  conv2d_379 (Conv2D)            (None, 3, 3, 512)    2359808     ['activation_352[0][0]']
#
#  batch_normalization_381 (Batch  (None, 3, 3, 512)   2048        ['conv2d_379[0][0]']
#  Normalization)
#
#  activation_353 (Activation)    (None, 3, 3, 512)    0           ['batch_normalization_381[0][0]']
#
#  conv2d_380 (Conv2D)            (None, 3, 3, 2048)   1050624     ['activation_353[0][0]']
#
#  batch_normalization_382 (Batch  (None, 3, 3, 2048)  8192        ['conv2d_380[0][0]']
#  Normalization)
#
#  add_110 (Add)                  (None, 3, 3, 2048)   0           ['batch_normalization_382[0][0]',
#                                                                   'activation_351[0][0]']
#
#  activation_354 (Activation)    (None, 3, 3, 2048)   0           ['add_110[0][0]']
#
#  dropout_30 (Dropout)           (None, 3, 3, 2048)   0           ['activation_354[0][0]']
#
#  average_pooling2d_4 (AveragePo  (None, 1, 1, 2048)  0           ['dropout_30[0][0]']
#  oling2D)
#
#  flatten_6 (Flatten)            (None, 2048)         0           ['average_pooling2d_4[0][0]']
#
#  dense_7 (Dense)                (None, 5)            10245       ['flatten_6[0][0]']
#
# ==================================================================================================
# Total params: 23,590,149
# Trainable params: 23,537,029
# Non-trainable params: 53,120
# __________________________________________________________________________________________________

# %%
resnet_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.01),
               loss='categorical_crossentropy',
               metrics='accuracy')

# %%
# Fit data
epochs = 50
history = resnet_model.fit_generator(
    train_generator,
    steps_per_epoch = num_train_samples // batch_size,
    epochs=epochs,
    validation_data = validation_generator,
    validation_steps = num_validation_samples // batch_size, 
)
# Out:
# Epoch 1/50
# C:\Users\markd\AppData\Local\Temp\ipykernel_32848\3654479111.py:3: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = resnet_model.fit_generator(
# 377/377 [==============================] - 21s 55ms/step - loss: 0.9425 - accuracy: 0.6350 - val_loss: 1.0986 - val_accuracy: 0.6128
# Epoch 2/50
# 377/377 [==============================] - 20s 53ms/step - loss: 0.9452 - accuracy: 0.6325 - val_loss: 1.0997 - val_accuracy: 0.6138
# Epoch 3/50
# 377/377 [==============================] - 21s 54ms/step - loss: 0.9477 - accuracy: 0.6304 - val_loss: 1.1304 - val_accuracy: 0.6084
# Epoch 4/50
# 377/377 [==============================] - 20s 52ms/step - loss: 0.9486 - accuracy: 0.6301 - val_loss: 1.1253 - val_accuracy: 0.6118
# Epoch 5/50
# 377/377 [==============================] - 20s 52ms/step - loss: 0.9479 - accuracy: 0.6288 - val_loss: 1.1116 - val_accuracy: 0.6077
# Epoch 6/50
# 377/377 [==============================] - 19s 51ms/step - loss: 0.
# 377/377 [==============================] - 19s 51ms/step - loss: 0.9037 - accuracy: 0.6486 - val_loss: 1.1539 - val_accuracy: 0.6070
# Epoch 48/50
# 377/377 [==============================] - 20s 52ms/step - loss: 0.9029 - accuracy: 0.6488 - val_loss: 1.1720 - val_accuracy: 0.6192
# Epoch 49/50
# 377/377 [==============================] - 19s 49ms/step - loss: 0.9016 - accuracy: 0.6540 - val_loss: 1.1492 - val_accuracy: 0.6185
# Epoch 50/50
# 377/377 [==============================] - 19s 49ms/step - loss: 0.9046 - accuracy: 0.6481 - val_loss: 1.1038 - val_accuracy: 0.6226

# %%
plot_acc(history)
plot_loss(history)

# %%
resnet_model2 = modified_ResNet50(dropout=0.3)
resnet_model2.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.01),
               loss='categorical_crossentropy',
               metrics='accuracy')
resnet_model2.summary()
# Out:
# Model: "model_5"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_9 (InputLayer)           [(None, 48, 48, 1)]  0           []
#
#  zero_padding2d_8 (ZeroPadding2  (None, 54, 54, 1)   0           ['input_9[0][0]']
#  D)
#
#  conv2d_381 (Conv2D)            (None, 25, 25, 64)   1664        ['zero_padding2d_8[0][0]']
#
#  batch_normalization_383 (Batch  (None, 25, 25, 64)  256         ['conv2d_381[0][0]']
#  Normalization)
#
#  activation_355 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_383[0][0]']
#
#  max_pooling2d_12 (MaxPooling2D  (None, 12, 12, 64)  0           ['activation_355[0][0]']
#  )
#
#  dropout_31 (Dropout)           (None, 12, 12, 64)   0           ['max_pooling2d_12[0][0]']
#
#  conv2d_382 (Conv2D)            (None, 12, 12, 64)   4160        ['dropout_31[0][0]']
#
#  batch_normalization_384 (Batch  (None, 12, 12, 64)  256         ['conv2d_382[0][0]']
#  Normalization)
#
#  activation_356 (Activation)    (None, 12, 12, 64)   0           ['batch_normalization_384[0][0]']
#
#  conv2d_383 (Conv2D)            (None, 12, 12, 64)   36928       ['activation_356[0][0]']
#
#  batch_normalization_385 (Batch  (None, 12, 12, 64)  256         ['conv2d_383[0][0]']
#  Normalization)
#
#  activation_357 (Activation)    (None, 12, 12, 64)   0           ['batch_normalization_385[0][0]']
#
#  conv2d_384 (Conv2D)            (None, 12, 12, 256)  16640       ['activation_357[0][0]']
#
#  conv2d_385 (Conv2D)            (None, 12, 12, 256)  16640       ['dropout_31[0][0]']
#
#  batch_normalization_386 (Batch  (None, 12, 12, 256)  1024       ['conv2d_384[0][0]']
#  Normalization)
#
#  batch_normalization_387 (Batch  (None, 12, 12, 256)  1024       ['conv2d_385[0][0]']
#  Normalization)
#
#  add_111 (Add)                  (None, 12, 12, 256)  0           ['batch_normalization_386[0][0]',
#                                                                   'batch_normalization_387[0][0]']
#
#  activation_358 (Activation)    (None, 12, 12, 256)  0           ['add_111[0][0]']
#
#  conv2d_386 (Conv2D)            (None, 12, 12, 64)   16448       ['activation_358[0][0]']
#
#  batch_normalization_388 (Batch  (None, 12, 12, 64)  256         ['conv2d_386[0][0]']
#  Normalization)
#
#  activation_359 (Activation)    (None, 12, 12, 64)   0           ['batch_normalization_388[0][0]']
#
#  conv2d_387 (Conv2D)            (None, 12, 12, 64)   36928       ['activation_359[0][0]']
#
#  batch_normalization_389 (Batch  (None, 12, 12, 64)  256         ['conv2d_387[0][0]']
#  Normalization)
#
#  activation_360 (Activation)    (None, 12, 12, 64)   0           ['batch_normalization_389[0][0]']
#
#  conv2d_388 (Conv2D)            (None, 12, 12, 256)  16640       ['activation_360[0][0]']
#
#  batch_normalization_390 (Batch  (None, 12, 12, 256)  1024       ['conv2d_388[0][0]']
#  Normalization)
#
#  add_112 (Add)                  (None, 12, 12, 256)  0           ['batch_normalization_390[0][0]',
#                                                                   'activation_358[0][0]']
#
#  activation_361 (Activation)    (None, 12, 12, 256)  0           ['add_112[0][0]']
#
#  conv2d_389 (Conv2D)            (None, 12, 12, 64)   16448       ['activation_361[0][0]']
#
#  batch_normalization_391 (Batch  (None, 12, 12, 64)  256         ['conv2d_389[0][0]']
#  Normalization)
#
#  activation_362 (Activation)    (None, 12, 12, 64)   0           ['batch_normalization_391[0][0]']
#
#  conv2d_390 (Conv2D)            (None, 12, 12, 64)   36928       ['activation_362[0][0]']
#
#  batch_normalization_392 (Batch  (None, 12, 12, 64)  256         ['conv2d_390[0][0]']
#  Normalization)
#
#  activation_363 (Activation)    (None, 12, 12, 64)   0           ['batch_normalization_392[0][0]']
#
#  conv2d_391 (Conv2D)            (None, 12, 12, 256)  16640       ['activation_363[0][0]']
#
#  batch_normalization_393 (Batch  (None, 12, 12, 256)  1024       ['conv2d_391[0][0]']
#  Normalization)
#
#  add_113 (Add)                  (None, 12, 12, 256)  0           ['batch_normalization_393[0][0]',
#                                                                   'activation_361[0][0]']
#
#  activation_364 (Activation)    (None, 12, 12, 256)  0           ['add_113[0][0]']
#
#  dropout_32 (Dropout)           (None, 12, 12, 256)  0           ['activation_364[0][0]']
#
#  conv2d_392 (Conv2D)            (None, 6, 6, 128)    32896       ['dropout_32[0][0]']
#
#  batch_normalization_394 (Batch  (None, 6, 6, 128)   512         ['conv2d_392[0][0]']
#  Normalization)
#
#  activation_365 (Activation)    (None, 6, 6, 128)    0           ['batch_normalization_394[0][0]']
#
#  conv2d_393 (Conv2D)            (None, 6, 6, 128)    147584      ['activation_365[0][0]']
#
#  batch_normalization_395 (Batch  (None, 6, 6, 128)   512         ['conv2d_393[0][0]']
#  Normalization)
#
#  activation_366 (Activation)    (None, 6, 6, 128)    0           ['batch_normalization_395[0][0]']
#
#  conv2d_394 (Conv2D)            (None, 6, 6, 512)    66048       ['activation_366[0][0]']
#
#  conv2d_395 (Conv2D)            (None, 6, 6, 512)    131584      ['dropout_32[0][0]']
#
#  batch_normalization_396 (Batch  (None, 6, 6, 512)   2048        ['conv2d_394[0][0]']
#  Normalization)
#
#  batch_normalization_397 (Batch  (None, 6, 6, 512)   2048        ['conv2d_395[0][0]']
#  Normalization)
#
#  add_114 (Add)                  (None, 6, 6, 512)    0           ['batch_normalization_396[0][0]',
#                                                                   'batch_normalization_397[0][0]']
#
#  activation_367 (Activation)    (None, 6, 6, 512)    0           ['add_114[0][0]']
#
#  conv2d_396 (Conv2D)            (None, 6, 6, 128)    65664       ['activation_367[0][0]']
#
#  batch_normalization_398 (Batch  (None, 6, 6, 128)   512         ['conv2d_396[0][0]']
#  Normalization)
#
#  activation_368 (Activation)    (None, 6, 6, 128)    0           ['batch_normalization_398[0][0]']
#
#  conv2d_397 (Conv2D)            (None, 6, 6, 128)    147584      ['activation_368[0][0]']
#
#  batch_normalization_399 (Batch  (None, 6, 6, 128)   512         ['conv2d_397[0][0]']
#  Normalization)
#
#  activation_369 (Activation)    (None, 6, 6, 128)    0           ['batch_normalization_399[0][0]']
#
#  conv2d_398 (Conv2D)            (None, 6, 6, 512)    66048       ['activation_369[0][0]']
#
#  batch_normalization_400 (Batch  (None, 6, 6, 512)   2048        ['conv2d_398[0][0]']
#  Normalization)
#
#  add_115 (Add)                  (None, 6, 6, 512)    0           ['batch_normalization_400[0][0]',
#                                                                   'activation_367[0][0]']
#
#  activation_370 (Activation)    (None, 6, 6, 512)    0           ['add_115[0][0]']
#
#  conv2d_399 (Conv2D)            (None, 6, 6, 128)    65664       ['activation_370[0][0]']
#
#  batch_normalization_401 (Batch  (None, 6, 6, 128)   512         ['conv2d_399[0][0]']
#  Normalization)
#
#  activation_371 (Activation)    (None, 6, 6, 128)    0           ['batch_normalization_401[0][0]']
#
#  conv2d_400 (Conv2D)            (None, 6, 6, 128)    147584      ['activation_371[0][0]']
#
#  batch_normalization_402 (Batch  (None, 6, 6, 128)   512         ['conv2d_400[0][0]']
#  Normalization)
#
#  activation_372 (Activation)    (None, 6, 6, 128)    0           ['batch_normalization_402[0][0]']
#
#  conv2d_401 (Conv2D)            (None, 6, 6, 512)    66048       ['activation_372[0][0]']
#
#  batch_normalization_403 (Batch  (None, 6, 6, 512)   2048        ['conv2d_401[0][0]']
#  Normalization)
#
#  add_116 (Add)                  (None, 6, 6, 512)    0           ['batch_normalization_403[0][0]',
#                                                                   'activation_370[0][0]']
#
#  activation_373 (Activation)    (None, 6, 6, 512)    0           ['add_116[0][0]']
#
#  conv2d_402 (Conv2D)            (None, 6, 6, 128)    65664       ['activation_373[0][0]']
#
#  batch_normalization_404 (Batch  (None, 6, 6, 128)   512         ['conv2d_402[0][0]']
#  Normalization)
#
#  activation_374 (Activation)    (None, 6, 6, 128)    0           ['batch_normalization_404[0][0]']
#
#  conv2d_403 (Conv2D)            (None, 6, 6, 128)    147584      ['activation_374[0][0]']
#
#  batch_normalization_405 (Batch  (None, 6, 6, 128)   512         ['conv2d_403[0][0]']
#  Normalization)
#
#  activation_375 (Activation)    (None, 6, 6, 128)    0           ['batch_normalization_405[0][0]']
#
#  conv2d_404 (Conv2D)            (None, 6, 6, 512)    66048       ['activation_375[0][0]']
#
#  batch_normalization_406 (Batch  (None, 6, 6, 512)   2048        ['conv2d_404[0][0]']
#  Normalization)
#
#  add_117 (Add)                  (None, 6, 6, 512)    0           ['batch_normalization_406[0][0]',
#                                                                   'activation_373[0][0]']
#
#  activation_376 (Activation)    (None, 6, 6, 512)    0           ['add_117[0][0]']
#
#  dropout_33 (Dropout)           (None, 6, 6, 512)    0           ['activation_376[0][0]']
#
#  conv2d_405 (Conv2D)            (None, 3, 3, 256)    131328      ['dropout_33[0][0]']
#
#  batch_normalization_407 (Batch  (None, 3, 3, 256)   1024        ['conv2d_405[0][0]']
#  Normalization)
#
#  activation_377 (Activation)    (None, 3, 3, 256)    0           ['batch_normalization_407[0][0]']
#
#  conv2d_406 (Conv2D)            (None, 3, 3, 256)    590080      ['activation_377[0][0]']
#
#  batch_normalization_408 (Batch  (None, 3, 3, 256)   1024        ['conv2d_406[0][0]']
#  Normalization)
#
#  activation_378 (Activation)    (None, 3, 3, 256)    0           ['batch_normalization_408[0][0]']
#
#  conv2d_407 (Conv2D)            (None, 3, 3, 1024)   263168      ['activation_378[0][0]']
#
#  conv2d_408 (Conv2D)            (None, 3, 3, 1024)   525312      ['dropout_33[0][0]']
#
#  batch_normalization_409 (Batch  (None, 3, 3, 1024)  4096        ['conv2d_407[0][0]']
#  Normalization)
#
#  batch_normalization_410 (Batch  (None, 3, 3, 1024)  4096        ['conv2d_408[0][0]']
#  Normalization)
#
#  add_118 (Add)                  (None, 3, 3, 1024)   0           ['batch_normalization_409[0][0]',
#                                                                   'batch_normalization_410[0][0]']
#
#  activation_379 (Activation)    (None, 3, 3, 1024)   0           ['add_118[0][0]']
#
#  conv2d_409 (Conv2D)            (None, 3, 3, 256)    262400      ['activation_379[0][0]']
#
#  batch_normalization_411 (Batch  (None, 3, 3, 256)   1024        ['conv2d_409[0][0]']
#  Normalization)
#
#  activation_380 (Activation)    (None, 3, 3, 256)    0           ['batch_normalization_411[0][0]']
#
#  conv2d_410 (Conv2D)            (None, 3, 3, 256)    590080      ['activation_380[0][0]']
#
#  batch_normalization_412 (Batch  (None, 3, 3, 256)   1024        ['conv2d_410[0][0]']
#  Normalization)
#
#  activation_381 (Activation)    (None, 3, 3, 256)    0           ['batch_normalization_412[0][0]']
#
#  conv2d_411 (Conv2D)            (None, 3, 3, 1024)   263168      ['activation_381[0][0]']
#
#  batch_normalization_413 (Batch  (None, 3, 3, 1024)  4096        ['conv2d_411[0][0]']
#  Normalization)
#
#  add_119 (Add)                  (None, 3, 3, 1024)   0           ['batch_normalization_413[0][0]',
#                                                                   'activation_379[0][0]']
#
#  activation_382 (Activation)    (None, 3, 3, 1024)   0           ['add_119[0][0]']
#
#  conv2d_412 (Conv2D)            (None, 3, 3, 256)    262400      ['activation_382[0][0]']
#
#  batch_normalization_414 (Batch  (None, 3, 3, 256)   1024        ['conv2d_412[0][0]']
#  Normalization)
#
#  activation_383 (Activation)    (None, 3, 3, 256)    0           ['batch_normalization_414[0][0]']
#
#  conv2d_413 (Conv2D)            (None, 3, 3, 256)    590080      ['activation_383[0][0]']
#
#  batch_normalization_415 (Batch  (None, 3, 3, 256)   1024        ['conv2d_413[0][0]']
#  Normalization)
#
#  activation_384 (Activation)    (None, 3, 3, 256)    0           ['batch_normalization_415[0][0]']
#
#  conv2d_414 (Conv2D)            (None, 3, 3, 1024)   263168      ['activation_384[0][0]']
#
#  batch_normalization_416 (Batch  (None, 3, 3, 1024)  4096        ['conv2d_414[0][0]']
#  Normalization)
#
#  add_120 (Add)                  (None, 3, 3, 1024)   0           ['batch_normalization_416[0][0]',
#                                                                   'activation_382[0][0]']
#
#  activation_385 (Activation)    (None, 3, 3, 1024)   0           ['add_120[0][0]']
#
#  conv2d_415 (Conv2D)            (None, 3, 3, 256)    262400      ['activation_385[0][0]']
#
#  batch_normalization_417 (Batch  (None, 3, 3, 256)   1024        ['conv2d_415[0][0]']
#  Normalization)
#
#  activation_386 (Activation)    (None, 3, 3, 256)    0           ['batch_normalization_417[0][0]']
#
#  conv2d_416 (Conv2D)            (None, 3, 3, 256)    590080      ['activation_386[0][0]']
#
#  batch_normalization_418 (Batch  (None, 3, 3, 256)   1024        ['conv2d_416[0][0]']
#  Normalization)
#
#  activation_387 (Activation)    (None, 3, 3, 256)    0           ['batch_normalization_418[0][0]']
#
#  conv2d_417 (Conv2D)            (None, 3, 3, 1024)   263168      ['activation_387[0][0]']
#
#  batch_normalization_419 (Batch  (None, 3, 3, 1024)  4096        ['conv2d_417[0][0]']
#  Normalization)
#
#  add_121 (Add)                  (None, 3, 3, 1024)   0           ['batch_normalization_419[0][0]',
#                                                                   'activation_385[0][0]']
#
#  activation_388 (Activation)    (None, 3, 3, 1024)   0           ['add_121[0][0]']
#
#  conv2d_418 (Conv2D)            (None, 3, 3, 256)    262400      ['activation_388[0][0]']
#
#  batch_normalization_420 (Batch  (None, 3, 3, 256)   1024        ['conv2d_418[0][0]']
#  Normalization)
#
#  activation_389 (Activation)    (None, 3, 3, 256)    0           ['batch_normalization_420[0][0]']
#
#  conv2d_419 (Conv2D)            (None, 3, 3, 256)    590080      ['activation_389[0][0]']
#
#  batch_normalization_421 (Batch  (None, 3, 3, 256)   1024        ['conv2d_419[0][0]']
#  Normalization)
#
#  activation_390 (Activation)    (None, 3, 3, 256)    0           ['batch_normalization_421[0][0]']
#
#  conv2d_420 (Conv2D)            (None, 3, 3, 1024)   263168      ['activation_390[0][0]']
#
#  batch_normalization_422 (Batch  (None, 3, 3, 1024)  4096        ['conv2d_420[0][0]']
#  Normalization)
#
#  add_122 (Add)                  (None, 3, 3, 1024)   0           ['batch_normalization_422[0][0]',
#                                                                   'activation_388[0][0]']
#
#  activation_391 (Activation)    (None, 3, 3, 1024)   0           ['add_122[0][0]']
#
#  conv2d_421 (Conv2D)            (None, 3, 3, 256)    262400      ['activation_391[0][0]']
#
#  batch_normalization_423 (Batch  (None, 3, 3, 256)   1024        ['conv2d_421[0][0]']
#  Normalization)
#
#  activation_392 (Activation)    (None, 3, 3, 256)    0           ['batch_normalization_423[0][0]']
#
#  conv2d_422 (Conv2D)            (None, 3, 3, 256)    590080      ['activation_392[0][0]']
#
#  batch_normalization_424 (Batch  (None, 3, 3, 256)   1024        ['conv2d_422[0][0]']
#  Normalization)
#
#  activation_393 (Activation)    (None, 3, 3, 256)    0           ['batch_normalization_424[0][0]']
#
#  conv2d_423 (Conv2D)            (None, 3, 3, 1024)   263168      ['activation_393[0][0]']
#
#  batch_normalization_425 (Batch  (None, 3, 3, 1024)  4096        ['conv2d_423[0][0]']
#  Normalization)
#
#  add_123 (Add)                  (None, 3, 3, 1024)   0           ['batch_normalization_425[0][0]',
#                                                                   'activation_391[0][0]']
#
#  activation_394 (Activation)    (None, 3, 3, 1024)   0           ['add_123[0][0]']
#
#  dropout_34 (Dropout)           (None, 3, 3, 1024)   0           ['activation_394[0][0]']
#
#  conv2d_424 (Conv2D)            (None, 3, 3, 512)    524800      ['dropout_34[0][0]']
#
#  batch_normalization_426 (Batch  (None, 3, 3, 512)   2048        ['conv2d_424[0][0]']
#  Normalization)
#
#  activation_395 (Activation)    (None, 3, 3, 512)    0           ['batch_normalization_426[0][0]']
#
#  conv2d_425 (Conv2D)            (None, 3, 3, 512)    2359808     ['activation_395[0][0]']
#
#  batch_normalization_427 (Batch  (None, 3, 3, 512)   2048        ['conv2d_425[0][0]']
#  Normalization)
#
#  activation_396 (Activation)    (None, 3, 3, 512)    0           ['batch_normalization_427[0][0]']
#
#  conv2d_426 (Conv2D)            (None, 3, 3, 2048)   1050624     ['activation_396[0][0]']
#
#  conv2d_427 (Conv2D)            (None, 3, 3, 2048)   2099200     ['dropout_34[0][0]']
#
#  batch_normalization_428 (Batch  (None, 3, 3, 2048)  8192        ['conv2d_426[0][0]']
#  Normalization)
#
#  batch_normalization_429 (Batch  (None, 3, 3, 2048)  8192        ['conv2d_427[0][0]']
#  Normalization)
#
#  add_124 (Add)                  (None, 3, 3, 2048)   0           ['batch_normalization_428[0][0]',
#                                                                   'batch_normalization_429[0][0]']
#
#  activation_397 (Activation)    (None, 3, 3, 2048)   0           ['add_124[0][0]']
#
#  conv2d_428 (Conv2D)            (None, 3, 3, 512)    1049088     ['activation_397[0][0]']
#
#  batch_normalization_430 (Batch  (None, 3, 3, 512)   2048        ['conv2d_428[0][0]']
#  Normalization)
#
#  activation_398 (Activation)    (None, 3, 3, 512)    0           ['batch_normalization_430[0][0]']
#
#  conv2d_429 (Conv2D)            (None, 3, 3, 512)    2359808     ['activation_398[0][0]']
#
#  batch_normalization_431 (Batch  (None, 3, 3, 512)   2048        ['conv2d_429[0][0]']
#  Normalization)
#
#  activation_399 (Activation)    (None, 3, 3, 512)    0           ['batch_normalization_431[0][0]']
#
#  conv2d_430 (Conv2D)            (None, 3, 3, 2048)   1050624     ['activation_399[0][0]']
#
#  batch_normalization_432 (Batch  (None, 3, 3, 2048)  8192        ['conv2d_430[0][0]']
#  Normalization)
#
#  add_125 (Add)                  (None, 3, 3, 2048)   0           ['batch_normalization_432[0][0]',
#                                                                   'activation_397[0][0]']
#
#  activation_400 (Activation)    (None, 3, 3, 2048)   0           ['add_125[0][0]']
#
#  conv2d_431 (Conv2D)            (None, 3, 3, 512)    1049088     ['activation_400[0][0]']
#
#  batch_normalization_433 (Batch  (None, 3, 3, 512)   2048        ['conv2d_431[0][0]']
#  Normalization)
#
#  activation_401 (Activation)    (None, 3, 3, 512)    0           ['batch_normalization_433[0][0]']
#
#  conv2d_432 (Conv2D)            (None, 3, 3, 512)    2359808     ['activation_401[0][0]']
#
#  batch_normalization_434 (Batch  (None, 3, 3, 512)   2048        ['conv2d_432[0][0]']
#  Normalization)
#
#  activation_402 (Activation)    (None, 3, 3, 512)    0           ['batch_normalization_434[0][0]']
#
#  conv2d_433 (Conv2D)            (None, 3, 3, 2048)   1050624     ['activation_402[0][0]']
#
#  batch_normalization_435 (Batch  (None, 3, 3, 2048)  8192        ['conv2d_433[0][0]']
#  Normalization)
#
#  add_126 (Add)                  (None, 3, 3, 2048)   0           ['batch_normalization_435[0][0]',
#                                                                   'activation_400[0][0]']
#
#  activation_403 (Activation)    (None, 3, 3, 2048)   0           ['add_126[0][0]']
#
#  dropout_35 (Dropout)           (None, 3, 3, 2048)   0           ['activation_403[0][0]']
#
#  average_pooling2d_5 (AveragePo  (None, 1, 1, 2048)  0           ['dropout_35[0][0]']
#  oling2D)
#
#  flatten_7 (Flatten)            (None, 2048)         0           ['average_pooling2d_5[0][0]']
#
#  dense_8 (Dense)                (None, 5)            10245       ['flatten_7[0][0]']
#
# ==================================================================================================
# Total params: 23,590,149
# Trainable params: 23,537,029
# Non-trainable params: 53,120
# __________________________________________________________________________________________________

# %%
# Fit data
epochs = 100
history2 = resnet_model2.fit_generator(
    train_generator,
    steps_per_epoch = num_train_samples // batch_size,
    epochs=epochs,
    validation_data = validation_generator,
    validation_steps = num_validation_samples // batch_size, 
)

plot_acc(history2)
plot_loss(history2)
# Out:
# Epoch 1/100
# C:\Users\markd\AppData\Local\Temp\ipykernel_32848\636140095.py:3: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history2 = resnet_model2.fit_generator(
# 377/377 [==============================] - 19s 51ms/step - loss: 1.1698 - accuracy: 0.5284 - val_loss: 1.1473 - val_accuracy: 0.5686
# Epoch 2/100
# 377/377 [==============================] - 22s 59ms/step - loss: 1.1179 - accuracy: 0.5526 - val_loss: 1.1627 - val_accuracy: 0.5791
# Epoch 3/100
# 377/377 [==============================] - 21s 56ms/step - loss: 1.0888 - accuracy: 0.5690 - val_loss: 1.1145 - val_accuracy: 0.5866
# Epoch 4/100
# 377/377 [==============================] - 21s 56ms/step - loss: 1.0570 - accuracy: 0.5801 - val_loss: 1.1238 - val_accuracy: 0.5842
# Epoch 5/100
# 377/377 [==============================] - 19s 50ms/step - loss: 1.0408 - accuracy: 0.5893 - val_loss: 1.1281 - val_accuracy: 0.5992
# Epoch 6/100
# 377/377 [==============================] - 19s 51ms/step - loss: 1.0304 - accuracy: 0.5948 - val_loss: 1.1287 - val_accuracy: 0.6002
# Epoch 7/100
# 377/377 [==============================] - 19s 50ms/step - loss: 1.0186 - accuracy: 0.5971 - val_loss: 1.1112 - val_accuracy: 0.5968
# Epoch 8/100
# 377/377 [==============================] - 19s 50ms/step - loss: 1.0082 - accuracy: 0.6069 - val_loss: 1.1236 - val_accuracy: 0.6016
# Epoch 9/100
# 377/377 [==============================] - 19s 51ms/step - loss: 0.9934 - accuracy: 0.6121 - val_loss: 1.1016 - val_accuracy: 0.6005
# Epoch 10/100
# 377/377 [==============================] - 19s 51ms/step - loss: 0.9863 - accuracy: 0.6116 - val_loss: 1.1302 - val_accuracy: 0.6107
# Epoch 11/100
# 377/377 [==============================] - 19s 50ms/step - loss: 0.9907 - accuracy: 0.6118 - val_loss: 1.1242 - val_accuracy: 0.6022
# Epoch 12/100
# 377/377 [==============================] - 19s 51ms/step - loss: 0.9823 - accuracy: 0.6113 - val_loss: 1.1083 - val_accuracy: 0.5985
# Epoch 13/100
# 377/377 [==============================] - 19s 51ms/step - loss: 0.9707 - accuracy: 0.6214 - val_loss: 1.0939 - val_accuracy: 0.6073
# Epoch 14/100
# 377/377 [==============================] - 19s 51ms/step - loss: 0.9678 - accuracy: 0.6219 - val_loss: 1.1124 - val_accuracy: 0.5982
# Epoch 15/100
# 377/377 [==============================] - 20s 54ms/step - loss: 0.9664 - accuracy: 0.6210 - val_loss: 1.1033 - val_accuracy: 0.6036
# Epoch 16/100
# 377/377 [==============================] - 19s 51ms/step - loss: 0.
100
# 377/377 [==============================] - 19s 51ms/step - loss: 0.9209 - accuracy: 0.6418 - val_loss: 1.1010 - val_accuracy: 0.6216
# Epoch 85/100
# 377/377 [==============================] - 19s 51ms/step - loss: 0.9136 - accuracy: 0.6470 - val_loss: 1.1418 - val_accuracy: 0.6253
# Epoch 86/100
# 377/377 [==============================] - 22s 57ms/step - loss: 0.9160 - accuracy: 0.6431 - val_loss: 1.1440 - val_accuracy: 0.5978
# Epoch 87/100
# 377/377 [==============================] - 19s 51ms/step - loss: 0.9200 - accuracy: 0.6451 - val_loss: 1.1595 - val_accuracy: 0.6090
# Epoch 88/100
# 377/377 [==============================] - 21s 56ms/step - loss: 0.9178 - accuracy: 0.6454 - val_loss: 1.1191 - val_accuracy: 0.6162
# Epoch 89/100
# 377/377 [==============================] - 20s 52ms/step - loss: 0.9129 - accuracy: 0.6473 - val_loss: 1.1036 - val_accuracy: 0.6063
# Epoch 90/100
# 377/377 [==============================] - 19s 51ms/step - loss: 0.9094 - accuracy: 0.6475 - val_loss: 1.1357 - val_accuracy: 0.6131
# Epoch 91/100
# 377/377 [==============================] - 19s 51ms/step - loss: 0.9124 - accuracy: 0.6429 - val_loss: 1.1114 - val_accuracy: 0.6026
# Epoch 92/100
# 377/377 [==============================] - 22s 59ms/step - loss: 0.9180 - accuracy: 0.6471 - val_loss: 1.1606 - val_accuracy: 0.6087
# Epoch 93/100
# 377/377 [==============================] - 21s 56ms/step - loss: 0.9210 - accuracy: 0.6407 - val_loss: 1.1018 - val_accuracy: 0.6209
# Epoch 94/100
# 377/377 [==============================] - 19s 51ms/step - loss: 0.9093 - accuracy: 0.6483 - val_loss: 1.1328 - val_accuracy: 0.6158
# Epoch 95/100
# 377/377 [==============================] - 19s 51ms/step - loss: 0.9073 - accuracy: 0.6493 - val_loss: 1.1404 - val_accuracy: 0.6128
# Epoch 96/100
# 377/377 [==============================] - 20s 52ms/step - loss: 0.9109 - accuracy: 0.6480 - val_loss: 1.1468 - val_accuracy: 0.6226
# Epoch 97/100
# 377/377 [==============================] - 19s 52ms/step - loss: 0.9167 - accuracy: 0.6481 - val_loss: 1.1276 - val_accuracy: 0.6250
# Epoch 98/100
# 377/377 [==============================] - 20s 53ms/step - loss: 0.9130 - accuracy: 0.6445 - val_loss: 1.1521 - val_accuracy: 0.6260
# Epoch 99/100
# 377/377 [==============================] - 20s 54ms/step - loss: 0.9084 - accuracy: 0.6447 - val_loss: 1.1960 - val_accuracy: 0.6274
# Epoch 100/100
# 377/377 [==============================] - 20s 52ms/step - loss: 0.9075 - accuracy: 0.6469 - val_loss: 1.1060 - val_accuracy: 0.6264

# %%
# DenseNet Implimentation
# Dense Block
def dense_block(X, f, filters, training=True, initializer = tf.keras.initializers.random_uniform):
    """
    Implementation of the dense block
    ONE LAYER (4 TOTAL): INPUT -> BN -> RELU -> 3x3 CONV
    Each layer is connnected to all layers after itself within the block
    
    Arguments:
    X -- input tensor of shape (m, n_H_prev, n_W_prev, n_C_prev)
    f -- integer, specifying the shape of the middle CONV's window for the main path
    filters -- python list of integers, defining the number of filters in the CONV layers of the main path
    training -- True: Behave in training mode
                False: Behave in inference mode
    initializer -- to set up the initial weights of a layer. Equals to random uniform initializer
    
    Returns:
    X -- output of the dense block, tensor of shape (m, n_H, n_W, n_C)
    """
    # Retrieve Filters
    F1, F2, F3 = filters
    
    # saving shortcut value
    X_shortcut = X
    
    # First component
    

    return X
